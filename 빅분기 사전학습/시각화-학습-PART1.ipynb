# %% [markdown]
# # Matplotlib을 이용한 시각화
# - https://matplotlib.org/3.1.1/gallery/index.html
# - https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# ![nn](./images/시각화-01.png)

# %% [markdown]
# ## figure

# %% [markdown]
# - Matplotlib에서 그래프(Axes, plot)는 Figure 객체내에 존재함
# - 그래프를 위한 새로운 Figure는 plt.figure() 함수를 통해 생성
# - plt.figure(번호, figsize=크기, dpi=1인치당 픽셀)
#     + Create a new figure, or activate an existing figure.
#     + cell에는 기본 figure가 설정되어 있음 : 0번
#     + 번호를 지정하면 지정한 번호의 figure에 그려짐, 입력된 번호의 figure가 없거나, 생략되면 새로운 figure 생성
#     + figsize=(가로크기, 세로크기)로 figure 크기 조절
#     + 크기 단위 : 인치, 기본 1인치 = 72 픽셀 (dpi를 사용해 조절 가능)
# - Cell : 텍스트를 포함한 사각형 (Cell은 여러 개의 Figure를 포함할 수 있음)
# - Figure : 전체 캔버스  (Figure는 여러 개의 Axes를 포함할 수 있음)
# - Axes : 1개 그래프 (Axes는 여러 개의 Plot을 포함할 수 있음)
# - Plot : 1개 선

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig0 = plt.figure(0, figsize=(1,2), dpi=100)
fig1 = plt.figure(1, figsize=(2,4))
figX = plt.figure(figsize=(5,1))

print(id(fig0), id(fig1), id(figX))

plt.figure(0)
plt.plot(np.arange(1,10,2))
plt.show()
# Out:
# 140636835732064 140636835731344 140636559401984

# %% [markdown]
# ## 선 그래프 (Line Plot)

# %% [markdown]
# - `plt.plot()` 함수 사용
# - `plt.plot([x], y, [fmt], [data])` 함수를 사용하여 x, y 축을 갖는 그래프 생성
#     - x, y : array-like or scalar
#     - fmt : str, optional, A format string, e.g. 'ro--' for red circles with dashed line
#     - 'ro--' : fmtcolor='red', marker='o', linestyle='dashed'
#     - data : indexable object, optional, DataFrame 같은 객체를 주면, x, y를 column 이름으로 줄 수 있음
# - plot 설명에서 색, marker 등에 대한 정보 확인
# - https://matplotlib.org/2.0.2/examples/color/named_colors.html
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# ### 하나의 선 그리기

# %% [markdown]
# - `plt.plot(y)` : x 는 [0,1,2,...] 자동 완성
# - `plt.plot(x, y)` : x,y 둘 다 지정, 갯수가 동일해야 함
# - `plt.plot(x, y, fmt)` : 선의 스타일 지정

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
score = pd.Series([1340, 1500, 2400, 3500, 4500, 5000, 5500, 4900, 4200, 3000, 2000, 1500], 
                  index= ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

# %%
plt.plot(score.values)
plt.show()

# %%
plt.plot(score.index, score.values)
plt.show()

# %%
# plt.plot(score.index, score.values, 'rs--')
plt.plot(score.index, score.values, color='green', marker='s', markersize=9, linestyle='dashed')
plt.show()

# %% [markdown]
# ### 여러 선 그리기

# %% [markdown]
# - 하나의 plot 함수에 여러 선 정보 입력 : `plt.plot(x, y, fmt, x2, y2, fmt2, ...)`
# - `plt.plot(x, y, fmt)` 여러 번 사용
#     + `plt.plot(X1, y1, fmt1)`
#     + `plt.plot(x2, y2, fmt2)`

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--', x, y2, 'gs--', x, y3, 'b^--')

plt.show()

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--')
plt.plot(x, y2, 'gs--')
plt.plot(x, y3, 'b^--')

plt.show()

# %% [markdown]
# ### x, y 축 레이블 표시

# %% [markdown]
# - `plt.xlabel(str, fontsize)` : x 축에 대한 레이블 표시
# - `plt.ylabel(str, fontsize)` : y 축에 대한 레이블 표시
# - `plt.title(str, fontsize)` : plot에 대한 제목

# %%
score = pd.Series([1340, 1500, 2400, 3500, 4500, 5000, 5500, 4900, 4200, 3000, 2000, 1500], 
                  index= ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

plt.figure(figsize=(7,5))
plt.plot(score, 'b--')
plt.title('Monthly Sales Volume', fontdict={'fontsize': 15})
plt.xlabel('Month')
plt.ylabel('Sales Volume')
plt.show()

# %% [markdown]
# ### x, y 측 특정 영역만 표시

# %% [markdown]
# - Limitation : 전체 데이터 중에 특정 영역만 표시
# - x, y 별도 설정
#     + `plt.xlim(min, max)`
#     + `plt.ylim(min, max)`
# - x, y 한번에 설정
#     + `plt.axis([xmin, xmax, ymin, ymax])`

# %%
score = pd.Series([1340, 1500, 2400, 3500, 4500, 5000, 5500, 4900, 4200, 3000, 2000, 1500], 
                  index= ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

plt.plot(score, 'b--')
plt.xlim('May', 'Sep')
plt.ylim(3000, 6000)
plt.show()

# %%
score = pd.Series([1340, 1500, 2400, 3500, 4500, 5000, 5500, 4900, 4200, 3000, 2000, 1500], 
                  index= ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

plt.plot(score, 'b--')
plt.axis(['May', 'Sep', 3000, 6000])
plt.show()

# %% [markdown]
# ### 범례 표시

# %% [markdown]
# - Legend(범례) 설정을 위해 그래프에 Label 이 있어야 함
# - 방법 1
#     + `plt.plot(x, y, style, label='text')`
#     + `plt.legend(loc='text')`
# - 방법 2
#     + plt.plot 에 Label 생략
#     + `plt.legend(labels=[label1, label2, ...], loc='text')`
# - loc : {upper left, upper center, upper right, center left, center, center right, lower left, lower center, lower right, best, right}

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--', label='red')
plt.plot(x, y2, 'gs--', label='green')
plt.plot(x, y3, 'b^--', label='blue')
plt.legend(loc='best')

plt.show()

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--', x, y2, 'gs--', x, y3, 'b^--')
plt.legend(labels=['red', 'green', 'blue'], loc='upper center')

plt.show()

# %% [markdown]
# ### 눈금선 표시

# %% [markdown]
# - `plt.grid()` : 눈금선 표시 (True 사용 가능)
# - `plt.grid(False)` : 눈금선 표시 안 함
# - `plt.grid(which='both', axis='both', color='gray', dashes=(3,3))`
#     + 종류 지정: which={'major', 'minor', 'both'}
#     + 축 지정 : axis={'both', 'x', 'y'}
#     + 점선 모양 지정 : dashes=(5,2,1,2) describes a sequence of 5 point and 1 point dashes separated by 2 point space
#     + 투명도 지정 : alpha=0~1
#     + linestyle, linewidth : 눈금선 모양과 두께지정 ('-','--','-.',':' 등)
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--', x, y2, 'gs--', x, y3, 'b^--')
plt.legend(labels=['red', 'green', 'blue'], loc='best')

# plt.grid(True)
# plt.grid(which='both', axis='y', color='gray', alpha=0.5, dashes=(5,2,1,2))
plt.grid(which='both', axis='y', color='red', alpha=0.5, linewidth=1, linestyle=':')

plt.show()

# %% [markdown]
# ### 눈금 간격 (Tick) 설정

# %% [markdown]
# - Ticks : 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
# - 방법 1: `ax = plt.axes()` 를 통해 axes 객체를 받아 작업
#     + `Axes.set_xticks(self, ticks, *, minor=False)`
#     + `Axes.set_yticks(self, ticks, *, minor=False)`
#     + 주 눈금 (Major Tick) 설정
#         - `ax.set_xticks(array-like)`
#         - `ax.set_yticks(array-link)`
#     + 보조 눈금 (Minor Tick) 설정
#         - `ax.set_xticks(array-like, minor=True)`
#         - `ax.set_yticks(array-link, minor=True)`
# - 방법 2 : plt.xticks 및 plt.yticks 사용
#     + `plt.xticks(ticks=None, labels=None, **kwargs)`, `plt.yticks(ticks=None, labels=None, **kwargs)`
#         - ticks : array-like, optional
#         - lables : array-like, optional
#         - kwargs : Text Property
#     + xticks: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html
#     + kwargs : https://matplotlib.org/stable/api/text_api.html#module-matplotlib.text
#     + `plt.tick_params()` : 눈금의 스타일 지정
#     + https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.tick_params.html

# %%
ax = plt.axes()

# %%
import matplotlib.ticker as ticker

x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3

ax = plt.axes()
ax.set_xticks(np.arange(1, 11, 2))
ax.set_yticks(np.arange(0, 1001, 200))
ax.set_xticks(np.arange(1, 11), minor=True)
ax.set_yticks(np.arange(0, 1001, 100), minor=True)

plt.plot(x, y1, 'ro--', x, y2, 'gs--')
plt.grid(which='major', axis='both', color='blue', dashes=(3,3))
plt.grid(which='minor', axis='both', color='gray', dashes=(3,3))

plt.show()

# %%
x = np.arange(1, 11)
y1 = x ** 2
y2 = x ** 3
y3 = x * 4

plt.plot(x, y1, 'ro--', x, y2, 'gs--', x, y3, 'b^--')
plt.legend(labels=['red','green','blue'], loc='best')

plt.xticks(ticks=np.arange(1,11,2), labels=['Jan', 'Mar', 'May', 'Jul', 'Sep'], rotation=0)
plt.yticks(ticks=np.arange(1,1100,150), labels=[f'{x}GB' for x in np.arange(0,1100,150)])

plt.grid()
plt.show()

# %% [markdown]
# ### 설명 화살표, 글 표시

# %% [markdown]
# - `plt.annotate(text, xy, xytext, arrowprops)` -> <b>매우 다양한 형식이 있음!</b>
#     + text : 표시할 문구
#     + xy : 화살표를 표시할 좌표
#     + xytext : 문구를 표시할 좌표
#     + arrowprops : 화살표 속성
# - annotations: https://matplotlib.org/stable/tutorials/text/annotations.html#annotations
# - `plt.text(x, y, text)`
#     + x, y : 문구 표시할 위치 좌표
#     + text : 표시할 문구

# %%
x = np.arange(1, 11)
y1 = 3 * x ** 2
y2 = 2 * x ** 3

plt.plot(x, y1, 'ro--', x, y2, 'gs--')
# here = 8, 1080 (arrow 위치), 7, 1350 (text 위치)
# 3x^2 = 8.5, 100
# 2x^3 = 8.5, 1100

plt.annotate('here', (8, 1080), (7, 1350), arrowprops={'color': 'blue'})
plt.text(8.5, 100, '$y=3x^2$')
plt.text(8.5, 1100, '$y=2x^3$')

plt.grid()
plt.show()

# %% [markdown]
# ## Subplot

# %% [markdown]
# - 여러 plot 을 나누어 표시
# - `plt.subplot(row, col, idx)`
#     + row, col : shape (행, 열)
#     + idx : 일련번호, 1 부터 시작
# - `figure, axes = plt.subplots(row, col, **kwargs)`
#     + row, col : shape (행, 열)
#     + sharex = True : x축을 공유한다는 의미
#     + sharey = True : y축을 공유한다는 의미
#     + constrained_layout = True : subplot 간 간격 확보 - 제목 달 떄
# - figure : 1개의 캔버스
# - axes : 캔버스 위에 그려지는 1개이 그래프
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %% [markdown]
# ![nn](./images/시각화-02.png)

# %%
name = ["Kim", "Yoon", "Choi", "Park"]
month = ["March", "April", "May", "June"]
data = {'name'    : month,
        'english' : [80, 90, 100, 95],
        'chinese' : [100, 80, 70, 85],
        'korean'  : [95, 100, 80, 60],
        'math'    : [90, 70, 60, 100]}
df = pd.DataFrame(data)
df
# Out:
#     name  english  chinese  korean  math
# 0  March       80      100      95    90
# 1  April       90       80     100    70
# 2    May      100       70      80    60
# 3   June       95       85      60   100

# %%
plt.subplot(2,2,1) # plt.subplot(221)
plt.plot('name', 'english', 'ro--', data=df)
plt.ylim(60, 100)
plt.grid()

plt.subplot(2,2,2) # plt.subplot(222)
plt.plot('name', 'chinese', 'gs--', data=df)
plt.ylim(60, 100)
plt.grid()

plt.subplot(2,2,3) # plt.subplot(223)
plt.plot('name', 'korean', 'b^--', data=df)
plt.ylim(60, 100)
# plt.grid()

plt.subplot(2,2,4) # plt.subplot(224)
plt.plot('name', 'math', 'm--', data=df)
plt.ylim(60, 100)
plt.grid()

plt.show()

# %%
x = 'name'
y = ['english','chinese','korean','math']
fmt = ['ro--','gs--','b^--','m--']
r, c = 2, 2

for number, idx in enumerate(range(r * c), start=221):
    plt.subplot(number)
    plt.plot(x, y[idx], fmt[idx], data=df)
    plt.ylim(60, 100)
    plt.grid(axis='y')

plt.show()

# %%
names = ['group_a','group_b','group_c']
values = [10, 50, 100]
graphs = [plt.bar, plt.scatter, plt.plot]

plt.figure(0, figsize=(10,3), facecolor='#ACFF44')

for location, idx in enumerate(range(3), start=131):
    plt.subplot(location)
    graphs[idx](names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %%
name = ["Kim", "Yoon", "Choi", "Park"]
month = ["March", "April", "May", "June"]
data = {'name'    : month,
        'english' : [80, 90, 100, 95],
        'chinese' : [100, 80, 70, 85],
        'korean'  : [95, 100, 80, 60],
        'math'    : [90, 70, 60, 100]}
df = pd.DataFrame(data)
df
# Out:
#     name  english  chinese  korean  math
# 0  March       80      100      95    90
# 1  April       90       80     100    70
# 2    May      100       70      80    60
# 3   June       95       85      60   100

# %%
x = 'name'
y = ['english','chinese','korean','math']
fmt = ['ro--','gs--','b^--','m--']
r, c = 2, 2

fig, axes = plt.subplots(r, c, sharex=True, sharey=True)

for axflat, cy, style in zip(axes.flat, y, fmt):  #for axflat, cy, style in zip(axes.flat, y[:r*c], fmt[:r*c]):
    axflat.plot(x, cy, style, data=df)
    # 축 (axis) ticks 지정, ticks 를 없앨 때 [] 사용
    axflat.set(xticks=[0,1,2,3], yticks=range(60,101,5))
    # axflat.axis('off') # axis 를 표시하지 않음
    axflat.axis(['March', 'June', 60, 100])
    axflat.grid()

plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# - 산점도, 산포도, 분산형 차트
# - 두 데이터간의 관계를 보기 위해 사용함
# - `plt.scatter(x, y, s, c, alpha)`
#     + s : scale
#     + c : color
#     + alpha : 투명도 (0 ~ 1)
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib-pyplot-scatter
# - line style 참조 : https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html#linestyles

# %%
np.random.seed(100)

x = np.arange(50)
y = x + np.random.rand(50) * 10
size = np.random.randint(10, 100, 50)
color = np.random.randint(200, 203, 50)

plt.scatter(x, y, s=size, c=color, alpha=0.7)

plt.show()

# %%
np.random.seed(100)

x = np.arange(50)
y = x + np.random.rand(50) * 10
size = np.random.randint(10, 100, 50)
color = np.random.randint(200, 203, 50)

ax = plt.axes()
ax.set_xticks(np.arange(0, 51, 10))
ax.set_yticks(np.arange(-10, 71, 10))
ax.set_xticks(np.arange(0, 51, 5), minor=True)
ax.set_yticks(np.arange(-10, 71, 5), minor=True)

plt.grid(which='both', color='gray', dashes=(3,3))

plt.scatter(x, y, s=size, c=color, alpha=0.7)

plt.show()

# %% [markdown]
# ## Bar Graph

# %% [markdown]
# - `plt.bar(x, y)` : 수직바
# - `plt.barh(x, y)` : 수평바
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib-pyplot-bar
# - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.barh.html

# %%
names = ['A', 'B', 'C']
values = [50, 30, 100]

plt.subplot(121)
plt.bar(names, height=values)

plt.subplot(122)
plt.barh(names, width=values)

plt.show()

# %%
# 여러 개의 bar 넣는 방법
np.random.seed(0)

data = np.random.randint(20, 70, (3,4))
x = np.arange(4)

for i, c in zip(range(len(data)), list('rgb')):
    plt.bar(x + i*0.25, data[i], color=c, width=0.25)

plt.legend(labels=['English','Chinese','Japanese'], loc='best')
plt.xticks(ticks=x+0.25, labels=['2017','2018','2019','2020'])
plt.yticks(ticks=np.arange(0, 80, 10))
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ## 히스토그램 (Histogram)

# %% [markdown]
# - 변수가 하나인 단변수 데이터의 빈도수를 그래프로 표현 (일변량 그래프)
# - 히스토그램을 그리기 위한 hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받음
# - 데이터 집계 결과를 반환
# - `n, bins, patches = plt.hist(x, bins, range)`
#     + x : 데이터
#     + bins : 계급 (x축의 값)
#     + range : 대상 범위, (min, max)
#     + n : 도수 (y축의 값 = 갯수)
#     + patches : 계급별 히스토그램 좌표와 높이
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html#matplotlib-pyplot-hist

# %%
np.random.seed(1)

x = np.random.normal(100, 15, 10000)

# 전체 범위에 대해 (별도 지정 필요없음). 50개 계급으로 나눈 히스토그램 그리기
n, bins, patches = plt.hist(x, 50)

plt.grid()
plt.show()

# %%
# 상기 예시에서 hist(x, 50) 을 통해 bins 를 50개(=50개의 구간) 으로 지정하였음
# 18~21 구간의 n (도수/y축) 의 값과 해당 구간의 데이터 (x축)를 확인  
print(n[18:22], bins[18:22])
# Out:
# [451. 533. 503. 552.] [86.64315989 88.94814663 91.25313337 93.55812012]

# %%
# 상기 예시에서 hist(x, 50) 을 통해 bins 를 50개(=50개의 구간) 으로 지정하였음
# 18~21 구간의 중간에 위치한 20번째 구간의 xy 값과 폭, 높이(y축) 확인
print(patches[20])
# Out:
# Rectangle(xy=(91.2531, 0), width=2.30499, height=503, angle=0)

# %%
np.random.seed(1)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# facecolor = 색상, 막대의 색상 지정
# density=True, y축을 확률밀도로 표시

plt.hist(x, 50, density=True, facecolor='green')

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.text(60, 0.025, f'$\mu={mu},\ \sigma={sigma}$')
plt.axis([40, 160, 0, 0.03])
plt.grid(False)

plt.show()

# %% [markdown]
# ## Pie Graph

# %% [markdown]
# - 전체에 대한 각 부분의 비율을 부채꼴 모양으로 나타낸 그래프
# - 각 부태꼴의 중심각이 전체에서 차지하는 비율을 나타내며, 비율을 한눈에 볼 수 있다는 장점이 있음
# - 전체적인 비율을 쉽게 파악할 수 있어서 언론사에서 통계 수치를 공개할 때 자주 활용됨
# - `plt.pie(data, labels, colors, autopct)`
#     + data : 데이터
#     + labels : 각 부채꼴의 레이블
#     + colors : 각 부채꼴의 색상
#     + autopct : 비율 표시 형식
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html#matplotlib-pyplot-pie

# %%
color = ['yellowgreen','gold','deepskyblue','red','lightgrey']
langs = ['Ruby','C','Java','Python','HTML5']
students = [7, 20, 15, 40, 10]

plt.figure(figsize=(6,4))
plt.pie(students, labels=langs, colors=color, autopct='%.2f%%')
plt.axis('equal')   # figuresize 를 유지하면서 pie chart 를 가운데 위치시킴
plt.title('Pie Chart')

plt.show()

# %% [markdown]
# ## 이미지 출력

# %% [markdown]
# - `plt.imshow(array-like or PIL)`
#     + PIL (Python Image Library) 의 Pillow 의 경우 RGB
#     + OpenCV 의 경우 BGR 의 반대 순서임
#     + 축의 눈금선 없애기 : `plt.axis('off')`
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
# !wget -N https://raw.githubusercontent.com/Soyoung-Yoon/data/main/cake.png
# Out:
# --2023-03-13 23:30:33--  https://raw.githubusercontent.com/Soyoung-Yoon/data/main/cake.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203813 (199K) [image/png]
# Saving to: 'cake.png'
#
# cake.png            100%[===================>] 199.04K  --.-KB/s    in 0.02s
#
# Last-modified header missing -- time-stamps turned off.
# 2023-03-13 23:30:33 (9.21 MB/s) - 'cake.png' saved [203813/203813]

# %%
# PIL (Python Image Library), Pillow 를 이용하는 방법
# img = Image.open(path)
# plt.imshow(img)
# RGB 순서

from PIL import Image

img = Image.open('./cake.png')
plt.imshow(img)
# plt.axis('off')

plt.show()

# %%
print(type(img), img, sep='\n')
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=233x343 at 0x7FE880ED2760>

# %%
# OpenCV 를 이용하는 방법
# img = cv2.imread(path)
# BGR 순서

import cv2

img = cv2.imread('./cake.png')
# img = img[..., ::-1]
plt.imshow(img)

plt.axis('off')
plt.show()

# %%
print(type(img), img.shape, img, sep='\n')
# Out:
# <class 'numpy.ndarray'>
# (343, 233, 3)
# [[[226 217 213]
#   [226 217 213]
#   [225 216 212]
#   ...
#   [202 235 248]
#   [203 236 249]
#   [209 236 248]]
#
#  [[226 217 213]
#   [226 217 213]
#   [225 216 212]
#   ...
#   [202 235 248]
#   [203 236 249]
#   [210 236 249]]
#
#  [[226 217 213]
#   [226 217 213]
#   [225 216 212]
#   ...
#   [202 235 248]
#   [203 236 249]
#   [210 237 249]]
#
#  ...
#
#  [[220 216 135]
#   [219 214 133]
#   [229 220 137]
#   ...
#   [173 176   5]
#   [174 178   1]
#   [173 178  10]]
#
#  [[217 213 132]
#   [216 212 131]
#   [228 218 134]
#   ...
#   [177 177   8]
#   [178 178   8]
#   [170 174   7]]
#
#  [[214 210 129]
#   [215 211 129]
#   [226 215 132]
#   ...
#   [178 176  11]
#   [179 174  14]
#   [166 171   7]]]

# %% [markdown]
# # Seaborn을 이용한 시각화

# %% [markdown]
# - seaborn : Statistical data visualization
# - matplotlib 를 기반으로 하는 Python Visualization 라이브러리
# - attractive 한 통계적 그래프를 제공하는 라이브러리
# - 공식 사이트 : https://seaborn.pydata.org
#     + boxplot
#     + swarmplot
#     + Implot
#     + heatmap
#     + pariplot
# - 참고 : https://portal-app.production-eks.codecademy.com/article/seaborn-design-i

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Seaborn의 스타일, 팔렛트

# %% [markdown]
# - `sns.set_style(style)` : 스타일 설정
#     + style : 'white', 'dark', 'whitegrid', 'darkgrid', ...
# - `x = sns.color_palette(palette)` : 팔렛트 객체 가져오기
# - `sns.set_palette(x)` : 팔렛트 설정
#     + palette : 'Set1', 'Pastel1', ...
#     + x : 팔렛트 객체
# - `sns.set_context(x)` : context 설정
#     + x : 'paper', 'poster', ...

# %%
# Line Plot 그리기
x = np.arange(1, 11, 0.2)
y1 = x ** 2
y2 = x ** 2.25
y3 = x ** 3

# sns.set_style('white')
# sns.set_style('whitegrid')
# sns.set_style('dark')
sns.set_style('darkgrid')

plt.figure(figsize=(5,3))
plt.plot(x, y1, x, y2, x, y3)

plt.show()

# %%
sns.set_style('whitegrid')

x = sns.color_palette('Set2')
sns.set_palette(x)

sns.set_context('paper')         

tips = sns.load_dataset('tips')
# sns.stripplot(x='day', y='total_bill', data=tips)
sns.stripplot(x='day', y='total_bill', data=tips, hue='day', legend=False)

plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 팔레트 값!
'''
'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 
'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',
'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 
'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 
'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 
'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 
'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 
'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 
'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 
'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 
'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 
'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 
'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 
'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 
'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 
'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 
'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 
'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 
'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r' ... 등등
'''
# Out:
# "\n'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', \n'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',\n'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', \n'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', \n'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', \n'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', \n'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', \n'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', \n'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', \n'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', \n'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', \n'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', \n'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', \n'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', \n'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', \n'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', \n'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', \n'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', \n'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r' ... 등등\n"

# %% [markdown]
# ## iris Data를 활용한 시각화 실습

# %% [markdown]
# ![nn](./images/시각화-03.png)

# %%
# 데이터 불러오기
# sns.load_dataset(데이터셋의 이름)
# iris(붓꼿) 데이터를 불러옴
# sepal : 꽃받침, petal : 꽃입

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
display(iris.species.unique())
iris.head()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### boxplot으로 분포 확인

# %% [markdown]
# - `seaborn.boxplot(*, x=None, y=None, hue=None, data=None)`
#     + x : x축 데이터
#     + y : y축 데이터
#     + hue : 범주형 입력 데이터
# - https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn-boxplot

# %% [markdown]
# ![nn](./images/시각화-04.png)

# %%
# 값의 분포를 boxplot으로 확인함
# x에 1D 값을 전달하면 수평, y에 1-D 값을 전달하면 수직
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))

sns.boxplot(y=iris['sepal_width'], data=iris)

# 값의 분포를 boxplot으로 확인함
# x에 1D 값을 전달하면 수평, y에 1-D 값을 전달하면 수직
plt.show()

# %%
# 특정 카테고리에 대한 값의 분포는 X,Y를 지정하여 확인 가능
# x, y에 값을 전달하고 둘 중 하나가 범주형이면 범주에 따른 값으로 나뉘어 출력
# data에 df을 지정해주면 x, y 전달 시 열의 레이블만 전달해도 됨

plt.figure(figsize=(8,6))

# sepal_width, species 에 대한 boxpklot
# sns.boxplot(x='species', y='sepal_width', data=iris)
sns.boxplot(x=iris.species, y=iris.sepal_width, data=iris)
# sns.boxplot(x=iris.sepal_width, y=iris.species, data=iris)

plt.show()

# %%
# 임의 데이터 추가 (범주형)
color = ['red','violet']
iris['color'] = [color[x] for x in np.random.randint(0, 2, 150)]
iris.color
# Out:
# 0         red
# 1      violet
# 2      violet
# 3         red
# 4      violet
#         ...
# 145    violet
# 146       red
# 147    violet
# 148    violet
# 149       red
# Name: color, Length: 150, dtype: object

# %%
# hue 옵션 : 범주형 입력 데이터 (카테고리 별 데이터 시각화 가능)
# palette 옵션을 통해 색상 지정 가능 
plt.figure(figsize=(8,6))

# 그래프 그리기, pallette='Dark2' 사용
sns.boxplot(x=iris.species, y=iris.sepal_length, hue=iris.color, data=iris, palette='Dark2')

plt.show()

# %%
# 팔레트 값!
'''
'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 
'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',
'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 
'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 
'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 
'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 
'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 
'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 
'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 
'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 
'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 
'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 
'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 
'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 
'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 
'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 
'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 
'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 
'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r' ... 등등
'''
# Out:
# "\n'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', \n'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',\n'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', \n'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', \n'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', \n'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', \n'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', \n'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', \n'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', \n'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', \n'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', \n'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', \n'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', \n'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', \n'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', \n'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', \n'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', \n'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', \n'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r' ... 등등\n"

# %% [markdown]
# ### swarmplot

# %% [markdown]
# - boxplot 보다 원본 데이터의 분포를 더 자세하게 확인할 떄 사용
# - `seaborn.swarmplot(*, x=None, y=None, hue=None, data=None)`
#     + x : x축 데이터
#     + y : y축 데이터
#     + hue : 범주형 입력 데이터
# - https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn-swarmplot

# %%
#swarmplot : 원본 데이터의 분포를 자세하게 확인

# swarmplot 그리기, color='.1' 사용  # 0:진한것, 1:보이지 않음
sns.swarmplot(x=iris.species, y=iris.sepal_length, data=iris, color='.1')

plt.show()

# %%
# boxplot(palette='Set1') + swarmplot(color='.5')
# x="species", y="sepal_length", hue='color', data = iris
plt.figure(figsize=(8,6))

sns.boxplot(x=iris.species, y=iris.sepal_length, hue=iris.color, data=iris, palette='Set1')
sns.swarmplot(x=iris.species, y=iris.sepal_length, hue=iris.color, data=iris, color='0.5')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:0.5'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### lmplot

# %% [markdown]
# - 단순 선형 회귀 그래프 생성
# - seaborn.lmplot(*, x=None, y=None, data=None, hue=None)
#    - x : x축 데이터
#    - y : y축 데이터
#    - hue : 범주형 입력 데이터
# - http://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
# Implot를 이용하여 단순 선형 회귀 그래프를 생성할 수 있음

# petal_width, petal_length에 대한 선형그래프
sns.set_style('darkgrid')
sns.lmplot(x='petal_width', y='petal_length', data=iris)

plt.show()

# %%
# hue 옵션에 범주형 데이터를 전달하면 클래스별 회귀선이 그려짐
sns.lmplot(x='petal_width', y='petal_length', hue='species', data=iris)


plt.show()

# %% [markdown]
# ### pairplot

# %% [markdown]
# - 각 변수 별 데이터 분포 및 변수간 관계를 분석
# - http://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
# pairplot을 이용하여 변수(컬럼)간 관계와 분포 확인 가능
# 같은것의 위치에서는 Kernel Density Estimation(커널밀도추정) 또는 히스토그램이 표시됨
#
# hue 옵션을 이용하여 카테고리별 분포를 볼 수  있음
sns.set_style('ticks')
sns.set_context('notebook')

sns.pairplot(data=iris, hue='species')

plt.show()

# %%
# vars 옵션을 이용하여 특정 변수만 지정 가능
# vars=['sepal_width', 'sepal_length']

sns.pairplot(data=iris, hue='species', vars=['sepal_width', 'sepal_length'])

plt.show()

# %%
# x_vars, y_vars 옵션을 사용하여 해당 축의 특정 변수만 지정 가능
# 이 경우 히스토그램 혹은 KDE가 출력되지 않을 수 있음
# x_vars=['sepal_width', 'sepal_length'], y_vars=['petal_width', 'petal_length']

sns.pairplot(data=iris, hue='species', x_vars=['sepal_width', 'sepal_length'], y_vars=['petal_width', 'petal_length'])

plt.show()

# %% [markdown]
# ### heatmap

# %% [markdown]
# - 두 개의 카테고리 값에 의한 값의 변화를 보고자 할 경우에 사용
# - 표출하고자 하는 데이터를 먼저 데이터 테이블 형태로 만들어야 함
# - http://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
# iris 의 상관계수 구하기
iris.corr()
# Out:
# /var/folders/3k/bgnrnfc15w792712mgb6g0_c0000gn/T/ipykernel_3255/3755736447.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# heapmap 함수를 사용하여 데이터 테이블 시각화
plt.figure(figsize=(7,6))

sns.heatmap(data=iris.corr())

plt.show()
# Out:
# /var/folders/3k/bgnrnfc15w792712mgb6g0_c0000gn/T/ipykernel_3255/3024992566.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=iris.corr())

# %%
# flights 데이터 세트 불러오기
flights = sns.load_dataset('flights')
display(flights.info())
flights.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB
# None
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# 해당 데이터를 heatmap으로 만들기 위해 'pivot' 함수를 사용하여 데이터 테이블 생성
flights_table = flights.pivot(index='month', columns='year', values='passengers')
flights_table
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# heapmap 함수를 사용하여 데이터 테이블 시각화
plt.figure(figsize=(10,5))
sns.heatmap(data=flights_table)
plt.show()

# %%
# annot 옵션을 통해 값 출력 가능
# fmt 옵션을 통해 데이터의 형식을 지정(d:정수, f:실수)
plt.figure(figsize=(10,5))
sns.heatmap(data=flights_table, annot=True, fmt='d')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data=flights_table, annot=True, fmt='d', cbar=False, cmap='YlGnBu')
plt.show()
