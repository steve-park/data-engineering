# %% [markdown]
# # 데이터 분석 실무
# ## 파이썬 라이브러리를 활용해서 통계 기법을 적용한 데이터 분석을 배우는 과정입니다.

# %% [markdown]
# #### 이번 시간은 제주도 관광데이터를 활용해서 분석을 해보는 시간입니다.
# * 먼저, 데이터를 불러오고 살펴보겠습니다.(jeju_2018.csv, encoding 'cp949')
# * 내국인 관광객 지역, 업종, 성별, 연령대별 카드 이용 데이터
# * https://www.jejudatahub.net/data/view/data/597

# %%
# 필요 라이브러리 import
import pandas as pd

# %%
# 데이터 불러오기
df_jeju = pd.read_csv('jeju_2018.csv', encoding='cp949')
df_jeju
# Out:
#      sido sigungu cityGubun marketType userType ageGroup gender  dtYearMonth  \
# 0     제주도     제주시        읍면         유흥     제주도민    60대이상      여       201812
# 1     제주도     제주시        읍면         유흥     제주도민    60대이상      남       201812
# 2     제주도     제주시        읍면         유흥     제주도민      50대      여       201812
# 3     제주도     제주시        읍면         유흥     제주도민      50대      남       201812
# 4     제주도     제주시        읍면         유흥     제주도민      40대      여       201812
# ...   ...     ...       ...        ...      ...      ...    ...          ...
# 8014  제주도    서귀포시        도심         교통   내국인관광객      30대      남       201801
# 8015  제주도    서귀포시        도심         교통   내국인관광객    20대미만      여       201801
# 8016  제주도    서귀포시        도심         교통   내국인관광객    20대미만      남       201801
# 8017  제주도    서귀포시        도심         교통   내국인관광객      20대      여       201801
# 8018  제주도    서귀포시        도심         교통   내국인관광객      20대      남       201801
#
#       userCount  useCount   useCost
# 0            23        29   4240100
# 1           114       190  27414000
# 2            52        71   6848000
# 3           259       458  91468500
# 4            77        99  10021600
# ...         ...       ...       ...
# 8014       1442      1691  70364681
# 8015          6         6    177975
# 8016          1         1     20000
# 8017        602       634  19857600
# 8018        692       756  29157095
#
# [8019 rows x 11 columns]

# %% [markdown]
# ##### 변수 요약
# * sido: 시도
# * sigungu: 시군구
# * cityGubun: 도심구분
# * marketType: 업종
# * userType: 관광객구분
# * ageGroup: 연령대
# * gender: 성별
# * dtYearMonth: 년월
# * userCount: 고객수
# * useCount: 사용횟수
# * useCost: 사용금액

# %% [markdown]
# #### 두 집단 간 차이 분석 : t-test

# %% [markdown]
# ##### 가설설정
# * 가설 1: 월별 남성과 여성의 이용 횟수의 차이가 있는지 여부를 검정한다.
# * 가설 2: 월별 20대와 30대의 이용 비용의 차이가 있는지 여부를 검정한다.
# * 가설 3: 월별 도심과 읍면 지역의 이용자 수의 차이가 있는지 여부를 검정한다.

# %%
# 필요 라이브러리 import
import pandas as pd
from scipy import stats

# %% [markdown]
# * 가설 1 검정

# %%
# 가설 1: 남성과 여성의 이용 횟수 비교
## 데이터 생성
male_data = df_jeju[df_jeju['gender'] == '남'][['useCount','dtYearMonth']].groupby('dtYearMonth').sum()
female_data = df_jeju[df_jeju['gender'] == '여'][['useCount','dtYearMonth']].groupby('dtYearMonth').sum()

# %%
male_data
# Out:
#              useCount
# dtYearMonth
# 201801        2124011
# 201802        1859953
# 201803        2183760
# 201804        2266748
# 201805        2402306
# 201806        2405125
# 201807        2538655
# 201808        2711957
# 201809        2397757
# 201810        2349726
# 201811        2197275
# 201812        2213203

# %%
## 검정통계량 계산
t_statistic, p_value = stats.ttest_ind(male_data, female_data)

print(p_value)
# Out:
# [7.98072469e-08]

# %%
## 결과 도출
if p_value < 0.05:
    print("남성과 여성의 이용 횟수는 통계적으로 유의미한 차이가 있습니다.")
else:
    print("남성과 여성의 이용 횟수는 통계적으로 유의미한 차이가 없습니다.")
# Out:
# 남성과 여성의 이용 횟수는 통계적으로 유의미한 차이가 있습니다.

# %% [markdown]
# * 가설 2 검정

# %%
# 가설 2: 20대와 30대의 이용 비용 비교
## 데이터 생성
age_20s_data = df_jeju[df_jeju['ageGroup'] == '20대'][['useCost','dtYearMonth']].groupby('dtYearMonth').sum()
age_30s_data = df_jeju[df_jeju['ageGroup'] == '30대'][['useCost','dtYearMonth']].groupby('dtYearMonth').sum()

# %%
## 검정통계량 계산
t_statistic, p_value = stats.ttest_ind(age_20s_data, age_30s_data)

print(p_value)

# %%
## 결과 도출
if p_value < 0.05:
    print("20대와 30대의 이용 비용은 통계적으로 유의미한 차이가 있습니다.")
else:
    print("20대와 30대의 이용 비용은 통계적으로 유의미한 차이가 없습니다.")

# %% [markdown]
# * 가설 3 검정

# %%
# 가설 3: 도심과 읍면 지역의 이용자 수 비교
## 데이터 생성
urban_data = df_jeju[df_jeju['cityGubun'] == '도심'][['userCount','dtYearMonth']].groupby('dtYearMonth').sum()
rural_data = df_jeju[df_jeju['cityGubun'] == '읍면'][['userCount','dtYearMonth']].groupby('dtYearMonth').sum()

# %%
## 검정통계량 계산
t_statistic, p_value = stats.ttest_ind(urban_data, rural_data)

print(p_value)

# %%
## 결과 도출
if p_value < 0.05:
    print("도심과 읍면 지역의 이용자 수는 통계적으로 유의미한 차이가 있습니다.")
else:
    print("도심과 읍면 지역의 이용자 수는 통계적으로 유의미한 차이가 없습니다.")

# %% [markdown]
# #### 세 집단 이상 차이 분석 : ANOVA

# %% [markdown]
# ##### 가설설정
# * 가설 1: 'marketType'에 따라 'userCount'가 유의미하게 다를까요?
# * 가설 2: 'ageGroup'에 따라 'userCount'가 유의미하게 다를까요?
# * 가설 3: 'marketType'과 'ageGroup'의 상호작용이 'userCount'에 유의미한 영향을 미치나요?

# %% [markdown]
# * 가설 1 검정

# %%
# 필요 라이브러리 import
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# 가설 1: marketType에 따른 userCount 차이 분산분석
## 데이터 생성
market_data = df_jeju[['userCount','marketType','dtYearMonth']].groupby(['marketType','dtYearMonth']).sum().reset_index()
market_data
# Out:
#    marketType  dtYearMonth  userCount
# 0          교통       201801     207486
# 1          교통       201802     186274
# 2          교통       201803     210007
# 3          교통       201804     212344
# 4          교통       201805     214701
# ..        ...          ...        ...
# 79         유흥       201808      35543
# 80         유흥       201809      36059
# 81         유흥       201810      33695
# 82         유흥       201811      32280
# 83         유흥       201812      35076
#
# [84 rows x 3 columns]

# %%
## 검정통계량 계산
model_1 = ols('userCount ~ marketType', data=market_data).fit()
anova_table_1 = sm.stats.anova_lm(model_1)

# %%
## 결과 도출
print("=== 가설 1: marketType에 따른 userCount 분산분석 결과 ===")
print(anova_table_1)
# Out:
# === 가설 1: marketType에 따른 userCount 분산분석 결과 ===
#               df        sum_sq       mean_sq           F        PR(>F)
# marketType   6.0  5.812829e+12  9.688048e+11  817.412545  1.484046e-67
# Residual    77.0  9.126110e+10  1.185209e+09         NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# DataFrame의 'marketType'과 'userCount' 열을 사용하여 사후 검정 수행
posthoc = pairwise_tukeyhsd(market_data['userCount'], market_data['marketType'])

# 사후 검정 결과 출력
print(posthoc)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
# group1 group2   meandiff   p-adj     lower        upper     reject
# ------------------------------------------------------------------
#     교통  문화/레져 -112218.6667    0.0  -154771.572  -69665.7613   True
#     교통     소매  -12863.8333  0.969  -55416.7387    29689.072  False
#     교통     쇼핑    448713.75    0.0  406160.8447  491266.6553   True
#     교통     숙박 -169053.6667    0.0  -211606.572 -126500.7613   True
#     교통    식음료  491712.6667    0.0  449159.7613   534265.572   True
#     교통     유흥    -177148.0    0.0 -219700.9053 -134595.0947   True
#  문화/레져     소매   99354.8333    0.0    56801.928  141907.7387   True
#  문화/레져     쇼핑  560932.4167    0.0  518379.5113   603485.322   True
#  문화/레져     숙박     -56835.0 0.0023  -99387.9053  -14282.0947   True
#  문화/레져    식음료  603931.3333    0.0   561378.428  646484.2387   True
#  문화/레져     유흥  -64929.3333 0.0003 -107482.2387   -22376.428   True
#     소매     쇼핑  461577.5833    0.0   419024.678  504130.4887   True
#     소매     숙박 -156189.8333    0.0 -198742.7387  -113636.928   True
#     소매    식음료     504576.5    0.0  462023.5947  547129.4053   True
#     소매     유흥 -164284.1667    0.0  -206837.072 -121731.2613   True
#     쇼핑     숙박 -617767.4167    0.0  -660320.322 -575214.5113   True
#     쇼핑    식음료   42998.9167  0.046     446.0113    85551.822   True
#     쇼핑     유흥   -625861.75    0.0 -668414.6553 -583308.8447   True
#     숙박    식음료  660766.3333    0.0   618213.428  703319.2387   True
#     숙박     유흥   -8094.3333 0.9973  -50647.2387    34458.572  False
#    식음료     유흥 -668860.6667    0.0  -711413.572 -626307.7613   True
# ------------------------------------------------------------------

# %% [markdown]
# * 가설 2 검정

# %%
# 필요 라이브러리 import
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# 가설 1: ageGroup에 따른 userCount 차이 분산분석
## 데이터 생성
age_data = df_jeju[['userCount','ageGroup','dtYearMonth']].groupby(['ageGroup','dtYearMonth']).sum().reset_index()
age_data.head(2)
# Out:
#   ageGroup  dtYearMonth  userCount
# 0      20대       201801     327011
# 1      20대       201802     333273

# %%
## 검정통계량 계산
model_2 = ols('userCount ~ ageGroup', data=age_data).fit()
anova_table_2 = sm.stats.anova_lm(model_2)

# %%
## 결과 도출
print("\n=== 가설 2: ageGroup에 따른 userCount 분산분석 결과 ===")
print(anova_table_2)
# Out:
# === 가설 2: ageGroup에 따른 userCount 분산분석 결과 ===
#             df        sum_sq       mean_sq           F        PR(>F)
# ageGroup   5.0  2.046611e+12  4.093223e+11  285.857361  2.684379e-43
# Residual  66.0  9.450612e+10  1.431911e+09         NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# DataFrame의 'marketType'과 'userCount' 열을 사용하여 사후 검정 수행
posthoc = pairwise_tukeyhsd(age_data['userCount'], age_data['ageGroup'])

# 사후 검정 결과 출력
print(posthoc)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
# group1 group2   meandiff   p-adj     lower        upper     reject
# ------------------------------------------------------------------
#    20대  20대미만 -337208.9167    0.0 -382551.3158 -291866.5175   True
#    20대    30대     124707.5    0.0   79365.1008  170049.8992   True
#    20대    40대     151564.0    0.0  106221.6008  196906.3992   True
#    20대    50대   31958.8333 0.3162  -13383.5658   77301.2325  False
#    20대  60대이상 -150560.6667    0.0 -195903.0658 -105218.2675   True
#  20대미만    30대  461916.4167    0.0  416574.0175  507258.8158   True
#  20대미만    40대  488772.9167    0.0  443430.5175  534115.3158   True
#  20대미만    50대    369167.75    0.0  323825.3508  414510.1492   True
#  20대미만  60대이상    186648.25    0.0  141305.8508  231990.6492   True
#    30대    40대      26856.5  0.512  -18485.8992   72198.8992  False
#    30대    50대  -92748.6667    0.0 -138091.0658  -47406.2675   True
#    30대  60대이상 -275268.1667    0.0 -320610.5658 -229925.7675   True
#    40대    50대 -119605.1667    0.0 -164947.5658  -74262.7675   True
#    40대  60대이상 -302124.6667    0.0 -347467.0658 -256782.2675   True
#    50대  60대이상    -182519.5    0.0 -227861.8992 -137177.1008   True
# ------------------------------------------------------------------

# %% [markdown]
# * 가설 3 검정

# %%
# 필요 라이브러리 import
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# 가설 1: ageGroup에 따른 userCount 차이 분산분석
## 데이터 생성
merge_data = df_jeju[['userCount','marketType','ageGroup','dtYearMonth']].groupby(['marketType','ageGroup','dtYearMonth']).sum().reset_index()
merge_data
# Out:
#     marketType ageGroup  dtYearMonth  userCount
# 0           교통      20대       201801      25392
# 1           교통      20대       201802      24796
# 2           교통      20대       201803      26976
# 3           교통      20대       201804      25429
# 4           교통      20대       201805      25366
# 5           교통      20대       201806      29397
# 6           교통      20대       201807      35202
# 7           교통      20대       201808      36100
# 8           교통      20대       201809      28921
# 9           교통      20대       201810      26146
# 10          교통      20대       201811      23863
# 11          교통      20대       201812      26563
# 12          교통    20대미만       201801        174
# 13          교통    20대미만       201802        178
# 14          교통    20대미만       201803        127
# 15          교통    20대미만       201804        143
# 16          교통    20대미만       201805        161
# 17          교통    20대미만       201806        144
# 18          교통    20대미만       201807        207
# 19          교통    20대미만       201808        236
# 20          교통    20대미만       201809        220
# 21          교통    20대미만       201810        216
# 22          교통    20대미만       201811        268
# 23          교통    20대미만       201812        349
# 24          교통      30대       201801      45368
# 25          교통      30대       201802      39224
# 26          교통      30대       201803      49965
# 27          교통      30대       201804      51299
# 28          교통      30대       201805      51594
# 29          교통      30대       201806      53836
# 30          교통      30대       201807      54625
# 31          교통      30대       201808      58673
# 32          교통      30대       201809      53454
# 33          교통      30대       201810      50071
# 34          교통      30대       201811      43950
# 35          교통      30대       201812      43306
# 36          교통      40대       201801      56423
# 37          교통      40대       201802      48947
# 38          교통      40대       201803      51931
# 39          교통      40대       201804      53693
# 40          교통      40대       201805      56849
# 41          교통      40대       201806      56694
# 42          교통      40대       201807      59718
# 43          교통      40대       201808      65088
# 44          교통      40대       201809      55417
# 45          교통      40대       201810      54912
# 46          교통      40대       201811      51866
# 47          교통      40대       201812      51114
# 48          교통      50대       201801      49632
# 49          교통      50대       201802      44264
# 50          교통      50대       201803      48306
# 51          교통      50대       201804      48766
# 52          교통      50대       201805      48571
# 136      문화/레져    60대이상       201805       9959
# 137      문화/레져    60대이상       201806       8769
# 138      문화/레져    60대이상       201807       7253
# 139      문화/레져    60대이상       201808       7969
# 140      문화/레져    60대이상       201809       8170
# 141      문화/레져    60대이상       201810       9144
# 142      문화/레져    60대이상       201811       8970
# 143      문화/레져    60대이상       201812       7880
# 144         소매      20대       201801      27690
# 145         소매      20대       201802      29717
# 146         소매      20대       201803      29628
# 147         소매      20대       201804      30058
# 148         소매      20대       201805      31186
# 149         소매      20대       201806      35805
# 150         소매      20대       201807      43450
# 151         소매      20대       201808      43292
# 152         소매      20대       201809      34301
# 153         소매      20대       201810      29755
# 154         소매      20대       201811      29214
# 155         소매      20대       201812      32328
# 156         소매    20대미만       201801       1018
# 157         소매    20대미만       201802       1118
# 158         소매    20대미만       201803       1940
# 159         소매    20대미만       201804       3154
# 160         소매    20대미만       201805       5346
# 161         소매    20대미만       201806       1990
# 162         소매    20대미만       201807       1649
# 163         소매    20대미만       201808       1803
# 164         소매    20대미만       201809       2696
# 165         소매    20대미만       201810       4192
# 166         소매    20대미만       201811       2481
# 167         소매    20대미만       201812       1695
# 168         소매      30대       201801      35129
# 169         소매      30대       201802      31061
# 170         소매      30대       201803      42099
# 171         소매      30대       201804      47807
# 172         소매      30대       201805      48520
# 173         소매      30대       201806      51016
# 174         소매      30대       201807      48182
# 175         소매      30대       201808      50930
# 176         소매      30대       201809      49666
# 177         소매      30대       201810      46702
# 178         소매      30대       201811      41521
# 179         소매      30대       201812      40057
# 180         소매      40대       201801      46225
# 181         소매      40대       201802      39838
# 182         소매      40대       201803      43381
# 183         소매      40대       201804      51365
# 184         소매      40대       201805      56155
# 185         소매      40대       201806      53628
# 186         소매      40대       201807      53546
# 187         소매      40대       201808      56404
# 188         소매      40대       201809      51361
# 189         소매      40대       201810      52345
# 190         소매      40대       201811      48976
# 191         소매      40대       201812      45705
# 192         소매      50대       201801      40498
# 193         소매      50대       201802      34548
# 194         소매      50대       201803      41339
# 195         소매      50대       201804      48656
# 196         소매      50대       201805      47474
# 197         소매      50대       201806      44748
# 198         소매      50대       201807      42325
# 199         소매      50대       201808      40959
# 200         소매      50대       201809      42443
# 201         소매      50대       201810      44785
# 202         소매      50대       201811      44493
# 203         소매      50대       201812      39807
# 204         소매    60대이상       201801      22040
# 205         소매    60대이상       201802      20608
# 206         소매    60대이상       201803      27054
# 207         소매    60대이상       201804      33165
# 208         소매    60대이상       201805      29817
# 209         소매    60대이상       201806      27887
# 210         소매    60대이상       201807      24819
# 211         소매    60대이상       201808      23147
# 212         소매    60대이상       201809      27146
# 213         소매    60대이상       201810      28807
# 214         소매    60대이상       201811      29276
# 215         소매    60대이상       201812      24268
# 216         쇼핑      20대       201801     115069
# 217         쇼핑      20대       201802     117875
# 218         쇼핑      20대       201803     115482
# 219         쇼핑      20대       201804     112219
# 220         쇼핑      20대       201805     117869
# 221         쇼핑      20대       201806     130512
# 222         쇼핑      20대       201807     153702
# 223         쇼핑      20대       201808     160057
# 224         쇼핑      20대       201809     130263
# 225         쇼핑      20대       201810     114172
# 226         쇼핑      20대       201811     107453
# 490         유흥      50대       201811       7788
# 491         유흥      50대       201812       8563
# 492         유흥    60대이상       201801       2853
# 493         유흥    60대이상       201802       2345
# 494         유흥    60대이상       201803       2951
# 495         유흥    60대이상       201804       2948
# 496         유흥    60대이상       201805       2874
# 497         유흥    60대이상       201806       2744
# 498         유흥    60대이상       201807       2510
# 499         유흥    60대이상       201808       2564
# 500         유흥    60대이상       201809       2748
# 501         유흥    60대이상       201810       2736
# 502         유흥    60대이상       201811       2713
# 503         유흥    60대이상       201812       3012

# %%
## 검정통계량 계산
model_3 = ols('userCount ~ marketType * ageGroup', data=merge_data).fit()
anova_table_3 = sm.stats.anova_lm(model_3)

# %%
## 결과 도출
print("\n=== 가설 3: marketType과 ageGroup의 상호작용이 userCount에 미치는 영향 분산분석 결과 ===")
print(anova_table_3)
# Out:
# === 가설 3: marketType과 ageGroup의 상호작용이 userCount에 미치는 영향 분산분석 결과 ===
#                         df        sum_sq       mean_sq            F  \
# marketType             6.0  9.688048e+11  1.614675e+11  2788.309495
# ageGroup               5.0  2.923731e+11  5.847461e+10  1009.771981
# marketType:ageGroup   30.0  2.775970e+11  9.253232e+09   159.789933
# Residual             462.0  2.675383e+10  5.790873e+07          NaN
#
#                             PR(>F)
# marketType            0.000000e+00
# ageGroup             4.776792e-246
# marketType:ageGroup  7.133941e-223
# Residual                       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# 상호작용항 만들기
merge_data['combi'] = merge_data['marketType'] + " / " + merge_data['ageGroup']
merge_data
# 사후 검정 결과 계산
posthoc = pairwise_tukeyhsd(merge_data['userCount'], merge_data['combi'])

# 사후 검정 결과 출력
pd.set_option('display.max_rows', None)
posthoc._results_table
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### 상관분석

# %%
# 필요 라이브러리 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터프레임의 변수 간 상관계수 계산
correlation_matrix = df_jeju.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 # 데이터프레임의 변수 간 상관계수 계산
# ----> 2 correlation_matrix = df_jeju.corr()
#
# File D:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File D:\Program Files\Python311\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File D:\Program Files\Python311\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '제주도'

# %%
# 상관계수 출력
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # 상관계수 출력
# ----> 2 print(correlation_matrix)
#
# NameError: name 'correlation_matrix' is not defined

# %%
# 상관계수를 히트맵으로 시각화
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # 상관계수를 히트맵으로 시각화
# ----> 2 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#       3 plt.title('Correlation Matrix')
#       4 plt.show()
#
# NameError: name 'correlation_matrix' is not defined

# %% [markdown]
# #### 회귀분석
# * 종속변수는 useCost
# * 독립변수는 marketType,	userType,	ageGroup,	gender

# %%
import pandas as pd
import statsmodels.api as sm

# 범주형 변수 변환
categorical_cols = ['marketType', 'userType', 'ageGroup', 'gender']
data_encoded = pd.get_dummies(df_jeju[['marketType', 'userType', 'ageGroup', 'gender','useCost']], columns=categorical_cols, drop_first=True)

# 독립변수/종속변수 설정
y = data_encoded['useCost']
X = data_encoded.drop('useCost', axis=1)

# 상수항 추가
X = sm.add_constant(X)

# 회귀식 도출
model = sm.OLS(y, X).fit()

# 결과 출력
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 16
#      13 X = sm.add_constant(X)
#      15 # 회귀식 도출
# ---> 16 model = sm.OLS(y, X).fit()
#      18 # 결과 출력
#      19 print(model.summary())
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
#     925     self._init_keys.remove("weights")
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     746 else:
#     747     weights = weights.squeeze()
# --> 748 super(WLS, self).__init__(endog, exog, missing=missing,
#     749                           weights=weights, hasconst=hasconst, **kwargs)
#     750 nobs = self.exog.shape[0]
#     751 weights = self.weights
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:202, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     201 def __init__(self, endog, exog, **kwargs):
# --> 202     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     203     self.pinv_wexog: Float64Array | None = None
#     204     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\data.py:84, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      82     self.orig_endog = endog
#      83     self.orig_exog = exog
# ---> 84     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      86 self.const_idx = None
#      87 self.k_constant = 0
#
# File D:\Program Files\Python311\Lib\site-packages\statsmodels\base\data.py:509, in PandasData._convert_endog_exog(self, endog, exog)
#     507 exog = exog if exog is None else np.asarray(exog)
#     508 if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509     raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                      "Check input data with np.asarray(data).")
#     511 return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
# Extract the regression results
results = pd.DataFrame({'coef': model.params, 'std_err': model.bse, 't_value': model.tvalues, 'p_value': model.pvalues})

# Print the results DataFrame
print(results)
