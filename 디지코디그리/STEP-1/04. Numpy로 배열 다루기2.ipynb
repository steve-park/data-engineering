# %% [markdown]
# # 파이썬 기초3 : AI 모델링과 데이터 사이언스를 위한 기초 과정
# * 본 과정은 파이썬 초심자을 위한 과정으로 AI 모델링과 데이터 사이언스를 위해 꼭 필요한 지식에 대해 배울 수 있습니다.
# * 본 과정을 모두 마칠 무렵이면 여러분은 파이썬으로 데이터를 다룰 수 있게될 겁니다.
# * 파이썬에 대한 모든 것을 다루지는 않습니다. 처음 AI 모델링과 데이터 사이언스를 시작할 때 꼭 필요한 내용을 중심으로 준비했습니다.

# %% [markdown]
# ## 4. Numpy로 배열 다루기2
# * 이번 시간에는 데이터 사이언스에서 많이 활용되는 배열을 다룰 수 있도록 도와주는 Numpy에 대해서 다루어 볼 예정입니다.
# * 특히 Numpy를 활용해서 배열의 형태를 확인 및 변경하고 타입을 확인하고 연산과 함수를 활용하는 방법에 대해 알아보겠습니다.

# %% [markdown]
# * Numpy 공식 Document
#     * https://numpy.org/

# %% [markdown]
# ### Q1. Numpy 배열의 형태를 확인하고 변경해봅시다.

# %% [markdown]
# #### 1. 배열의 형태 확인하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 형태를 확인하는 예시코드 만들어 주세요)

# %% [markdown]
# #### 2. 배열의 형태 변경하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 형태를 변경하는 예시코드 만들어 주세요)

# %% [markdown]
# ### Q2. Numpy로 배열의 데이터 타입을 확인하고 변경해봅시다.

# %% [markdown]
# #### 1. 배열의 데이터 타입 확인하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 데이터 타입을 확인하는 예시코드 만들어 주세요)

# %% [markdown]
# #### 2. 배열의 데이터 타입 변경하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 데이터 타입을 변경하는 예시코드 만들어 주세요)

# %% [markdown]
# ### Q3. Numpy로 배열의 연산을 해봅시다.

# %% [markdown]
# #### 1. Numpy의 벡터화 연산
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 벡터화 연산을 하는 예시코드 만들어 주세요)

# %% [markdown]
# #### 2. Numpy의 브로드캐스팅
# ![image.png](attachment:image.png)

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy를 활용해서 배열의 브로드캐스팅 연산을 하는 예시코드 만들어 주세요)

# %% [markdown]
# ### Q4. Numpy로 배열의 함수를 활용해봅시다.

# %% [markdown]
# #### 1. 배열의 최솟값, 최댓값 구하는 함수 활용하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy에서 배열의 최솟값, 최댓값 구하는 함수를 활용하는 예시코드 만들어 주세요)

# %% [markdown]
# #### 2. 배열의 평균 구하는 함수 활용하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy에서 배열의 평균 구하는 함수를 활용하는 예시코드 만들어 주세요)

# %% [markdown]
# #### 3. 행렬의 곱 구하는 함수 활용하기

# %%
# Chat GPT가 알려준 예시코드로 실습을 해봅시다.(Query : Numpy에서 행렬의 곱을 구하는 함수를 활용하는 예시코드 만들어 주세요)

# %% [markdown]
# ## Summary
# * 이번 시간에는 Numpy를 활용해서 배열의 형태를 확인 및 변경하고 타입을 확인하고 연산과 함수를 활용하는 방법에 대해서 다루어 봤습니다.
# * 다음 시간에는 Numpy로 배열을 결합/분리/정렬하고 요소를 추가/제거하는 방법에 대해서 다루어 보겠습니다.
